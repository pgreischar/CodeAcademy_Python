# %%
from matplotlib import pyplot as plt

# %%
x_values = [0, 1, 2, 3, 4]
y_values = [0, 1, 4, 9, 16]
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# Multiple Line Plots in Single axis

# %%
# Days of the week:
days = [0, 1, 2, 3, 4, 5, 6]
# Your Money:
money_spent = [17, 12, 12, 10, 14, 16, 10]
# Your Friend's Money:
money_spent_2 = [11, 4, 5, 15, 22, 21, 22]
# Plot your money:
plt.plot(days, money_spent, marker = '*')
# Plot your friend's money: (notice the different line style formatting)
plt.plot(days, money_spent_2,linestyle=':',color='#82edc9',marker='o')
# Above in linestyle you could also use a -- to be a dashed line & added a color / marker.
# Display the result:
# If you'd like to customize the axis, use:
plt.axis([1,5,0,30])
# Add Axes Labels:
plt.xlabel('Days')
plt.ylabel('Money Spent')
# Add a Title
plt.title ("Patrick's Awesome Graph")
plt.show()

# %% [markdown]
# Subplots:
# Sometimes, we want to display two lines side-by-side, rather than in the same set of x- and y-axes. When we have multiple axes in the same picture, we call each set of axes a subplot.
#
# The command plt.subplot() needs three arguments to be passed into it:
#
# The number of rows of subplots
# The number of columns of subplots
# The index of the subplot we want to create

# %%
# Data sets
x = [1, 2, 3, 4]
y = [4, 3, 4, 2]
z = [1, 2, 3, 4]

# First Subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, color='green')
plt.title('First Subplot')
plt.legend('Y Values Only')

# Second Subplot
plt.subplot(1, 2, 2)
plt.plot(x, z, color='steelblue')
plt.plot(x, y, color='green')
plt.title('Second Subplot')
plt.legend(["Z Values","y Values"], loc = 9)

# Display both subplots
plt.show()

# %% [markdown]
# Legends
# When we have multiple lines on a single graph we can label them by using the command plt.legend().  I added a legend to the second subplot above.
#
# These are the position values loc accepts:
#
# Number Code	String
# 0	best
# 1	upper right
# 2	upper left
# 3	lower left
# 4	lower right
# 5	right
# 6	center left
# 7	center right
# 8	lower center
# 9	upper center
# 10	center

# %% [markdown]
# Figures:
#     When we're making lots of plots, it's easy to end up with lines that have been plotted and not displayed. If we’re not careful, these "forgotten" lines will show up in your new plots. In order to be sure that you don't have any stray lines, you can use the command plt.close('all') to clear all existing plots before you plot a new one.
#
# Previously, we learned how to put two sets of axes into the same figure. Sometimes, we would rather have two separate figures. We can use the command plt.figure() to create new figures and size them how we want. We can add the keyword figsize=(width, height) to set the size of the figure, in inches. We use parentheses (( and )) to pass in the width and height, which are separated by a comma (,).

# %%
word_length = [8, 11, 12, 11, 13, 12, 9, 9, 7, 9]
power_generated = [753.9, 768.8, 780.1, 763.7, 788.5, 782, 787.2, 806.4, 806.2, 798.9]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

plt.close('all')
plt.figure()
plt.plot(years, word_length)
plt.savefig('winning_word_lengths.png')
plt.figure(figsize=(7, 3))
plt.plot(years, power_generated)
plt.savefig('power_generated.png')
